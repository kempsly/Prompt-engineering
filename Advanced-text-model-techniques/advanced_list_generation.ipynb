# %%
# %pip install openai --upgrade
# Out:
# Collecting openai
#   Downloading openai-1.50.2-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Downloading openai-1.50.2-py3-none-any.whl (382 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.0/383.0 kB 8.9 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.9 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.8 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 21.6 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jiter-0.5.0 openai-1.50.2

# %%
import openai
import re
import getpass


openai.api_key = getpass.getpass("Please enter your OpenAI Key:")
# Out:
# Please enter your OpenAI Key:··········

# %%
import json

# %%
def complete(prompt):
    response = openai.chat.completions.create(
        model="gpt-4",
        messages=[
            {
            "role": "user",
            "content": prompt
            }
        ],
    )
    return response.choices[0].message.content

complete("is this working?")
# Out:
# 'Yes, it is working. How can I assist you today?'

# %%
# Setup the article title
article = "What is data engineering?"
# Inject the article title into the base prompt
base_prompt = f'Write a numbered, hierarchical outline for an article on "{article}"\n\nHere is an example, of the structure:\n\n1. Introduction \n    a. Definition of digital marketing \n2. Types of Digital Marketing \n    a. Search Engine Optimization \n    b. Social Media Marketing \n    c. Content Marketing \n    d. Pay-Per-Click Advertising \n    e. Email Marketing \n3. Benefits of Digital Marketing \n    a. Cost-Effective \n    b. Targeted Audience \n    c. Measurable Results \n    d. Increased Reach \n\n----\n'

result = complete(base_prompt)
result

# Combine the two patterns so that we have a dictionary that looks like this:
# {
#     "1. Introduction": {"a.": "Definition of digital marketing"},
#     "2. Types of Digital Marketing": {
#         "a.": "Cost-Effective",
#         "b.": "Targeted Audience",
#         "c.": "Measurable Results",
#     },
# }
# Out:
# '1. Introduction \n    a. Definition of Data Engineering \n\n2. Fundamentals of Data Engineering \n    a. Need for Data Engineering \n    b. Overview of the Data Engineering process  \n    c. Role of a Data Engineer \n\n3. Key Concepts in Data Engineering \n    a. Data Architecture \n    b. Database Systems \n    c. Data Warehousing \n    d. ETL (Extraction, Transformation, Load) Process \n    e. Big Data Technologies \n    f. Data Governance \n\n4. Data Engineering Tools \n    a. SQL and NoSQL Databases \n    b. Hadoop Framework \n    c. Apache Spark \n    d. Data Modelling Tools \n    e. Cloud Storage Solutions\n\n5. Importance of Data Engineering \n    a. Importance in Business Intelligence \n    b. Role in Data Science  \n    c. Contribution to Machine Learning and AI \n    d. Support in Decision-Making \n\n6. Challenges in Data Engineering \n    a. Data Privacy and Security \n    b. Data Quality \n    c. Complexity in Data Processing \n    d. Managing Real-Time Data \n\n7. Skills Required for a Data Engineer \n    a. Knowledge in Programming Languages \n    b. Understanding of Databases \n    c. Proficiency in Big Data Technologies \n    d. Problem-Solving Skills \n    e. Communication Skills \n\n8. Conclusion \n    a. Future Trends in Data Engineering \n    b. The Increasing Demand for Data Engineers.'

# %%
print(result)
# Out:
# 1. Introduction
#     a. Definition of Data Engineering
#
# 2. Fundamentals of Data Engineering
#     a. Need for Data Engineering
#     b. Overview of the Data Engineering process
#     c. Role of a Data Engineer
#
# 3. Key Concepts in Data Engineering
#     a. Data Architecture
#     b. Database Systems
#     c. Data Warehousing
#     d. ETL (Extraction, Transformation, Load) Process
#     e. Big Data Technologies
#     f. Data Governance
#
# 4. Data Engineering Tools
#     a. SQL and NoSQL Databases
#     b. Hadoop Framework
#     c. Apache Spark
#     d. Data Modelling Tools
#     e. Cloud Storage Solutions
#
# 5. Importance of Data Engineering
#     a. Importance in Business Intelligence
#     b. Role in Data Science
#     c. Contribution to Machine Learning and AI
#     d. Support in Decision-Making
#
# 6. Challenges in Data Engineering
#     a. Data Privacy and Security
#     b. Data Quality
#     c. Complexity in Data Processing
#     d. Managing Real-Time Data
#
# 7. Skills Required for a Data Engineer
#     a. Knowledge in Programming Languages
#     b. Understanding of Databases
#     c. Proficiency in Big Data Technologies
#     d. Problem-Solving Skills
#     e. Communication Skills
#
# 8. Conclusion
#     a. Future Trends in Data Engineering
#     b. The Increasing Demand for Data Engineers.

# %%
# Extract main sections
main_sections = re.findall(r'\d+\..*?(?=^\d+|\Z)', result, re.MULTILINE | re.DOTALL)

# Extract sub-sections
sections = {}
for section in main_sections:
    section_title = re.search(r'\d+\..+', section).group(0)
    sub_sections = re.findall(r'\s+[a-z]\..+', section, re.MULTILINE)
    sections[section_title] = [heading.strip() for heading in  sub_sections]

# %%
print(sections)
# Out:
# {'1. Introduction ': ['a. Definition of Data Engineering'], '2. Fundamentals of Data Engineering ': ['a. Need for Data Engineering', 'b. Overview of the Data Engineering process', 'c. Role of a Data Engineer'], '3. Key Concepts in Data Engineering ': ['a. Data Architecture', 'b. Database Systems', 'c. Data Warehousing', 'd. ETL (Extraction, Transformation, Load) Process', 'e. Big Data Technologies', 'f. Data Governance'], '4. Data Engineering Tools ': ['a. SQL and NoSQL Databases', 'b. Hadoop Framework', 'c. Apache Spark', 'd. Data Modelling Tools', 'e. Cloud Storage Solutions'], '5. Importance of Data Engineering ': ['a. Importance in Business Intelligence', 'b. Role in Data Science', 'c. Contribution to Machine Learning and AI', 'd. Support in Decision-Making'], '6. Challenges in Data Engineering ': ['a. Data Privacy and Security', 'b. Data Quality', 'c. Complexity in Data Processing', 'd. Managing Real-Time Data'], '7. Skills Required for a Data Engineer ': ['a. Knowledge in Programming Languages', 'b. Understanding of Databases', 'c. Proficiency in Big Data Technologies', 'd. Problem-Solving Skills', 'e. Communication Skills'], '8. Conclusion ': ['a. Future Trends in Data Engineering', 'b. The Increasing Demand for Data Engineers.']}

# %%
prompt = "Produce an article outline for \"What is data engineering?\"\n\nHere is an example, of the structure. Always return valid JSON.\n\n{\n\"top_heading_one:\": [\"subheading_one\", \"subheading_two\"],\n\"top_heading_two:\": [\"subheading_one\", \"subheading_two\"],\n} \n\nRemember that the ouput must be like the above, and must be parsable JSON.\n\n----\n\n"
result = complete(prompt)

# %%
result
# Out:
# '{\n"Introduction": ["Definition of Data Engineering", "The importance of Data Engineering"],\n"What is Data Engineering?": ["Historical overview", "Key concepts and applications"],\n"Roles and Responsibilities of a Data Engineer": ["Data sourcing and collecting", "Designing and implementing databases & processing systems", "Data analysis and optimization"],\n"The Difference between Data Engineering and Data Science": ["Role differentiation", "Interconnection and dependency"],\n"Essential Skills for Data Engineers": ["Programming languages", "Database systems", "Data modeling and ETL tools", "Cloud platforms"],\n"The Data Engineering Landscape": ["Current Market Trends", "Leading Companies & Startups in Data Engineering", "Future Outlook"],\n"Conclusion": ["Impact of Data Engineering on businesses", "Career opportunities in Data Engineering"]\n}'

# %%
json.loads(result)
# Out:
# {'Introduction': ['Definition of Data Engineering',
#   'The importance of Data Engineering'],
#  'What is Data Engineering?': ['Historical overview',
#   'Key concepts and applications'],
#  'Roles and Responsibilities of a Data Engineer': ['Data sourcing and collecting',
#   'Designing and implementing databases & processing systems',
#   'Data analysis and optimization'],
#  'The Difference between Data Engineering and Data Science': ['Role differentiation',
#   'Interconnection and dependency'],
#  'Essential Skills for Data Engineers': ['Programming languages',
#   'Database systems',
#   'Data modeling and ETL tools',
#   'Cloud platforms'],
#  'The Data Engineering Landscape': ['Current Market Trends',
#   'Leading Companies & Startups in Data Engineering',
#   'Future Outlook'],
#  'Conclusion': ['Impact of Data Engineering on businesses',
#   'Career opportunities in Data Engineering']}

# %%
try:
  print(json.loads(result))
except Exception as e:
  # Re-running the gpt-4
  pass
  # Parsing the text and trying to extract the data from the string
# Out:
# {'Introduction': ['Definition of Data Engineering', 'The importance of Data Engineering'], 'What is Data Engineering?': ['Historical overview', 'Key concepts and applications'], 'Roles and Responsibilities of a Data Engineer': ['Data sourcing and collecting', 'Designing and implementing databases & processing systems', 'Data analysis and optimization'], 'The Difference between Data Engineering and Data Science': ['Role differentiation', 'Interconnection and dependency'], 'Essential Skills for Data Engineers': ['Programming languages', 'Database systems', 'Data modeling and ETL tools', 'Cloud platforms'], 'The Data Engineering Landscape': ['Current Market Trends', 'Leading Companies & Startups in Data Engineering', 'Future Outlook'], 'Conclusion': ['Impact of Data Engineering on businesses', 'Career opportunities in Data Engineering']}

# %%
# !pip install pyyaml

import yaml
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.2)

# %%
prompt = "Produce an article outline in the format a .yml file for \"What is data engineering?\"\n\nAlways return valid YML.\n\nHere is an example:\n\n- name: Example YAML File\n  description: This is an example YAML file.\n  sections:\n    - title: Introduction\n      content: |\n        This is the introduction.\n    - title: Conclusion\n      content: |\n        This is the conclusion.\n\n----\n\n\n"
text = complete(prompt)
text
# Out:
# '- name: What is Data Engineering?\n  description: An in-depth article discussing what data engineering is, its roles and responsibilities, importance, tools, and its distinction from data science.\n  sections:\n    - title: Introduction\n      content: |\n        Brief overview of what the article is about; define data engineering in general terms.\n\n    - title: Understanding Data Engineering\n      content: |\n        Dive deeper into the concept of data engineering; discuss its different aspects; explain why it is essential in today’s data-driven landscape.\n\n    - title: Roles and Responsibilities of a Data Engineer\n      content: |\n        Enumerate and explain various roles a data engineer holds; discuss the responsibilities that come with them.\n\n    - title: Importance of Data Engineering\n      content: |\n        Stress the value of data engineering in businesses, scientific research, etc.; discuss some potential consequences when ignored.\n\n    - title: Tools Used in Data Engineering\n      content: |\n        List down common tools used in data engineering and give a brief discussion for each.\n\n    - title: The Difference Between Data Engineering and Data Science\n      content: |\n        Compare and contrast data engineering and data science; help the audience understand that while they are closely intertwined, they play distinct roles in dealing with data.\n\n    - title: Conclusion\n      content: |\n        Summarize the main points from each section; highlight the importance of understanding the role of data engineering in a data-driven economy. \n\n    - title: References\n      content: |\n        Provide a list of sources and additional readings for those who want to dive deeper into data engineering.'

# %%
print(text)
# Out:
# - name: What is Data Engineering?
#   description: An in-depth article discussing what data engineering is, its roles and responsibilities, importance, tools, and its distinction from data science.
#   sections:
#     - title: Introduction
#       content: |
#         Brief overview of what the article is about; define data engineering in general terms.
#
#     - title: Understanding Data Engineering
#       content: |
#         Dive deeper into the concept of data engineering; discuss its different aspects; explain why it is essential in today’s data-driven landscape.
#
#     - title: Roles and Responsibilities of a Data Engineer
#       content: |
#         Enumerate and explain various roles a data engineer holds; discuss the responsibilities that come with them.
#
#     - title: Importance of Data Engineering
#       content: |
#         Stress the value of data engineering in businesses, scientific research, etc.; discuss some potential consequences when ignored.
#
#     - title: Tools Used in Data Engineering
#       content: |
#         List down common tools used in data engineering and give a brief discussion for each.
#
#     - title: The Difference Between Data Engineering and Data Science
#       content: |
#         Compare and contrast data engineering and data science; help the audience understand that while they are closely intertwined, they play distinct roles in dealing with data.
#
#     - title: Conclusion
#       content: |
#         Summarize the main points from each section; highlight the importance of understanding the role of data engineering in a data-driven economy.
#
#     - title: References
#       content: |
#         Provide a list of sources and additional readings for those who want to dive deeper into data engineering.

# %%
# Load the YAML string into a Python object
data = yaml.load(text, Loader=yaml.FullLoader)

# %%
print(data)
# Out:
# [{'name': 'What is Data Engineering?', 'description': 'An in-depth article discussing what data engineering is, its roles and responsibilities, importance, tools, and its distinction from data science.', 'sections': [{'title': 'Introduction', 'content': 'Brief overview of what the article is about; define data engineering in general terms.\n'}, {'title': 'Understanding Data Engineering', 'content': 'Dive deeper into the concept of data engineering; discuss its different aspects; explain why it is essential in today’s data-driven landscape.\n'}, {'title': 'Roles and Responsibilities of a Data Engineer', 'content': 'Enumerate and explain various roles a data engineer holds; discuss the responsibilities that come with them.\n'}, {'title': 'Importance of Data Engineering', 'content': 'Stress the value of data engineering in businesses, scientific research, etc.; discuss some potential consequences when ignored.\n'}, {'title': 'Tools Used in Data Engineering', 'content': 'List down common tools used in data engineering and give a brief discussion for each.\n'}, {'title': 'The Difference Between Data Engineering and Data Science', 'content': 'Compare and contrast data engineering and data science; help the audience understand that while they are closely intertwined, they play distinct roles in dealing with data.\n'}, {'title': 'Conclusion', 'content': 'Summarize the main points from each section; highlight the importance of understanding the role of data engineering in a data-driven economy. \n'}, {'title': 'References', 'content': 'Provide a list of sources and additional readings for those who want to dive deeper into data engineering.'}]}]
